# %%
import pandas as pd
import bz2
import json
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

# %%
DATA_FOLDER = 'data/'
RETURN_FILE_DATA = DATA_FOLDER+"known_speaker_gender_only_male_female.json.bz2"

# %%
GENDER_DICT = DATA_FOLDER + "dict_genders.json"
OCC_DICT = DATA_FOLDER + "dict_occupations.json"
CAT_OCC_DICT = DATA_FOLDER + "dict_categories_occupations.json"

# %%
with open(GENDER_DICT) as json_file:
    gender_dict = json.load(json_file)
with open(OCC_DICT) as json_file:
    occ_dict = json.load(json_file)
with open(CAT_OCC_DICT) as json_file:
    cat_occ_dict = json.load(json_file)

# %%
df = pd.read_json(RETURN_FILE_DATA)

# %% [markdown]
# Find the gender in the gender dictionnary

# %%
df['gender'] = [gender_dict[x] for x in df.gender.to_list()]

# %%
df.shape[0]
# Out:
# 68127

# %% [markdown]
# Drop the informations that are no use for us

# %%
df.drop(columns = ['quoteID','probas','urls','phase'], inplace=True);

# %% [markdown]
# Drop the speakers with no occupation

# %%
df.dropna(axis = 0, subset = ['occupation'], inplace = True)
df.shape[0]
# Out:
# 65950

# %% [markdown]
# # **CODE** si on garde que la première occupation

# %% [markdown]
# Keep only the first occupation of each speaker and read it thanks to the occupation dictionnary

# %%
df['occupation'] = df['occupation'].apply(lambda x: x[0])

# %%
for idx, row in df.iterrows():
        if row['occupation'] not in occ_dict.keys():
            df.drop(idx, inplace=True)

# %%
df['occupation'] = [occ_dict[x] for x in df.occupation.to_list()]

# %% [markdown]
# Create a new colums which puts the occupations into categories of occupations

# %%
df['categorie'] = 0

# %%
for idx, row in df.iterrows():
    if row['occupation'] not in cat_occ_dict.keys():
        df.categorie[idx]='Autre'
    else:
        df.categorie[idx]=cat_occ_dict[df.occupation[idx]]
# Out:
# <ipython-input-14-e94b9c8c3ae5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.categorie[idx]='Autre'
# /Users/potdevinjosephine/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# <ipython-input-14-e94b9c8c3ae5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.categorie[idx]=cat_occ_dict[df.occupation[idx]]

# %% [markdown]
# # **CODE** pour les années

# %% [markdown]
# Retrieve the year difference between the date of birth of the speaker and the appearence of his citation in the journals

# %%
df.dropna(axis = 0, subset = ['date_of_birth'], inplace = True)
df['date_of_birth'] = df['date_of_birth'].apply(lambda x: x[0][1:5])

# %%
df['year_of_age'] = 0
for idx, row in df.iterrows():
    df['year_of_age'][idx]=(df.date[idx].year-int(df.date_of_birth[idx]))
# Out:
# <ipython-input-16-0105ae3884af>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year_of_age'][idx]=(df.date[idx].year-int(df.date_of_birth[idx]))

# %%
df.drop(columns='date_of_birth', inplace=True)

# %% [markdown]
# As, every information needed is now in the DataFrame df, it is useful to sort it by the categories of occupation.

# %%
df.sort_values('categorie', inplace=True)
df.shape[0]
# Out:
# 58932

# %%
df
# Out:
#                                                quotation             speaker  \
# 99401  Samsung Galaxy M Series has proven to be a cus...       Manish Tiwary
# 18099  [ Kevin Feige ] wanted to make sure we didn't ...  Christopher Markus
# 18101  Further consideration will be given at this st...  Christopher Morgan
# 18102                         harm in this case is great  Christopher Morgan
# 58209  Where Sekiro varies a bit is in having a confl...        Ian Hamilton
# ...                                                  ...                 ...
# 60481       Let's put the breaks on the excitement here,          Remi Garde
# 60478  Let's keep it one thousand up here because my ...     Marcellus Wiley
# 60465  Let's be honest. The town centre has had its d...       Joe Robertson
# 60498  If Pukki had been playing for them, they would...         Paul Merson
# 48717                It was the culmination of our trip,          Mark Smith
#
#             qids                date  numOccurrences gender  \
# 99401  Q16222093 2019-09-18 10:18:36               1   male
# 18099   Q5112818 2019-08-03 16:30:57               1   male
# 18101  Q22348394 2019-05-30 06:00:00               3   male
# 18102  Q22348394 2019-02-06 03:27:39               7   male
# 58209  Q15446774 2019-04-08 02:10:49               1   male
# ...          ...                 ...             ...    ...
# 60481     Q12160 2019-03-08 07:27:00              12   male
# 60478  Q16205555 2019-08-21 01:52:25               1   male
# 60465  Q16875101 2019-11-28 05:02:17               2   male
# 60498    Q430740 2019-08-20 10:06:00               2   male
# 48717  Q10502635 2019-08-30 15:01:00               1   male
#
#                         occupation categorie  year_of_age
# 99401                film director    Artist           37
# 18099                 screenwriter    Artist           19
# 18101                film producer    Artist           77
# 18102                film producer    Artist           77
# 58209                       writer    Artist           73
# ...                            ...       ...          ...
# 60481  association football player    Sports           53
# 60478     American football player    Sports           45
# 60465            ice hockey player    Sports           71
# 60498  association football player    Sports           51
# 48717  association football player    Sports           55
#
# [58932 rows x 9 columns]

# %%
df_final = df.groupby(df.categorie)

# %%
df_final.head()
# Out:
#                                                quotation  \
# 99401  Samsung Galaxy M Series has proven to be a cus...
# 18099  [ Kevin Feige ] wanted to make sure we didn't ...
# 18101  Further consideration will be given at this st...
# 18102                         harm in this case is great
# 58209  Where Sekiro varies a bit is in having a confl...
# 89843  We can't remove debris to a landfill, for exam...
# 43565                    Who is the greatest competitor?
# 31641  My dad coached Nika and Erika a while back and...
# 31089  Or there's been a point where we lapse for 20 ...
# 90041  It's been throughout the entire Washington Str...
# 26239  Given the seriousness of these issues, which b...
# 94606  The bifurcation of winners and losers is what ...
# 26238  Cuba continues to play a destabilizing role in...
# 60583  so impressed with how @LibertyU students condu...
# 60585  continues to provide generous, reasonable, and...
# 51228  We believe it is inevitable more free games wi...
# 89416  This is a great club with a lot of history and...
# 97251  From Norman Cousins to Susan Sontag to Jimmy a...
# 45123  Dikgang Moseneke brings vast experience in hum...
# 45880  We must bring back tougher international restr...
# 34940      Do they even have to make such a delineation?
# 14215                  our enablement and our assistance
# 11823  There are currently more job openings than peo...
# 76583  as close as possible to adversaries and their ...
# 14802  This is the true and objective way in which yo...
# 32772  So I had never thought about those things to b...
# 39859  I hope that it's going to change for the bette...
# 7391   Batman v Superman: Dawn of Justice, Justice Le...
# 1663   Blessed beyond words. Thank you, God. I believ...
# 39859               1  female                        model            Model
# 7391                1    male                        model            Model
# 1663               13  female                        model            Model
# 1667                3  female                        model            Model
# 12483               1  female                   politician         Politics
# 53426               1    male                   politician         Politics
# 12478               1  female                   politician         Politics
# 80931               1    male                   politician         Politics
# 14648               1    male                   politician         Politics
# 44530               1    male              Catholic priest         Religion
# 92094               4    male                   theologian         Religion
# 53164               2    male              Catholic priest         Religion
# 46601               1    male              Catholic priest         Religion
# 98025               5    male              Catholic priest         Religion
# 53571               2  female                      chemist        Scientist
# 82873               1    male                mathematician        Scientist
# 47116               1    male                     engineer        Scientist
# 47118               1    male                     engineer        Scientist
# 46856               1    male                    physician        Scientist
# 52150               5  female                    historian  Social Sciences
# 90049               2    male                   journalist  Social Sciences
# 52149               3  female                    historian  Social Sciences
# 94595               1  female                   journalist  Social Sciences
# 86599               1    male                   journalist  Social Sciences
# 77571               4    male                    cricketer           Sports
# 80131               1    male     American football player           Sports
# 77652               1    male     Canadian football player           Sports
# 80130               1    male  association football player           Sports
# 77661               1    male  association football player           Sports
#
#        year_of_age
# 99401           37
# 18099           19
# 18101           77
# 18102           77
# 58209           73
# 89843           69
# 43565           48
# 31641           90
# 31089           33
# 90041           31
# 26239           57
# 94606           59
# 26238           57
# 60583           57
# 60585           73
# 51228           70
# 89416          107
# 97251           89
# 45123           52
# 45880           87
# 34940           89
# 14215           61
# 11823           73
# 76583           56
# 14802           77
# 32772           41
# 39859           38
# 7391            36
# 1663            22
# 1667            22
# 12483           63
# 53426           41
# 12478           63
# 80931           39
# 14648           70
# 44530           60
# 92094           70
# 53164           64
# 46601           71
# 98025           65
# 53571           64
# 82873           66
# 47116           51
# 47118           51
# 46856           74
# 52150           32
# 90049           68
# 52149           32
# 94595           63
# 86599           49
# 77571           46
# 80131           54
# 77652           61
# 80130           26
# 77661           27

# %% [markdown]
# # **CODE** si on regarde toutes les occupations

# %%
#for idx, row in df.iterrows():
#    x=0
 #   for i in range(len(row['occupation'])):
  #      if row['occupation'][i-x] not in occ_dict.keys():
   #         row['occupation'].remove(row['occupation'][i-x])
    #        x+=1

# %%
#for idx, row in df.iterrows():
 #   for i in range(len(row['occupation'])):
  #      row['occupation'][i]=occ_dict[row['occupation'][i]]

# %%
#df

# %% [markdown]
# # Problemes avec ce code et améliorations a faire

# %% [markdown]
# **1-** Il n'y a que des boucles for ou même des doubles boucles for. Le code marche mais (pour moi) il met du temps à run et il n'est surement pas optimisé

# %% [markdown]
# **2-** Je ne sais pas exactement quoi faire à la fin: retourner un groupby; retrouner df_final qui a sort les occupations; faire un sort_values sur quelque chose d'autre de plus pertinant?

# %% [markdown]
# **3-** Il faut que je fasse la même chose pour quand on garde toutes les occupations d'un speaker. Idée: mettre dans la colonne 'catégorie' une liste des catégories pour chaque occupation et ne garder à la fin dans la cellule, que la catégorie qui revient le plus.
