# %%
import pandas as pd
import bz2
import json
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from utils import quotes_by_gender, unique_speaker_per_gender, get_champlex
from collections import Counter
import math

# %%
DATA_FOLDER = 'data/'


DATA_2015 = DATA_FOLDER+"filtered-2015.json.bz2"
DATA_2016 = DATA_FOLDER+"filtered-2016.json.bz2"
DATA_2017_BEFORE = DATA_FOLDER + "filtered-2017-before.json.bz2"
DATA_2017_AFTER = DATA_FOLDER + "filtered-2017-after.json.bz2"
DATA_2018 = DATA_FOLDER+"filtered-2018.json.bz2"
DATA_2019 = DATA_FOLDER+"filtered-2019.json.bz2"
DATA_2020 = DATA_FOLDER+"filtered-2020.json.bz2"

# %%
def read_all_chunks(year, nb_chunk):
    chunks=[]
    for i in range(nb_chunk):
        chunks.append(pd.read_json(DATA_FOLDER+f'chunk-{str(i+1)}-{year}.json.bz2'))
    return pd.concat(chunks)

# %%
quotes_2020 = read_all_chunks('2020', 3)

# %%
quotes_2020.drop(['religion', 'ethnic_group'], axis = 1, inplace = True)
#print(quotes_2020.dropna().shape[0])

# %%
print((quotes_2020.dropna()).shape[0])
# Out:
# 111794

# %%
print('initial number of quotes in 2020:', quotes_2020.shape[0])
# Out:
# initial number of quotes in 2020: 1571363

# %%
print('If we drop all NaN, we are left with', quotes_2020.dropna().shape[0], 'quotes.')
print('It means that we loose', quotes_2020.shape[0] - quotes_2020.dropna().shape[0], 'quotes.')
# Out:
# If we drop all NaN, we are left with 33622 quotes.
# It means that we loose 1537741 quotes.

# %%
print('Number of quotes if we removed unknown ethnic_groups', quotes_2020.dropna(subset = ['ethnic_group']).shape[0])
print('We lost',  quotes_2020.shape[0]-quotes_2020.dropna(subset = ['ethnic_group']).shape[0], 'quotes')
# Out:
# Number of quotes if we removed unknown ethnic_groups 180957
# We lost 1390406 quotes

# %%
without_ethnic_group = quotes_2020.drop('ethnic_group', axis = 1)

# %%
print('If we remove the column ethnic group and drop all NaN, we are left with',
      without_ethnic_group.dropna().shape[0], 'quotes: we loose', quotes_2020.shape[0] - without_ethnic_group.dropna().shape[0], 'quotes')
# Out:
# If we remove the column ethnic group and drop all NaN, we are left with 88966 quotes: we loose 1482397 quotes

# %%
without_religion_and_ethnic_group = without_ethnic_group.drop('religion', axis = 1)

# %%
print('If we do not take religion neither ethnic group, we have', without_religion_and_ethnic_group.dropna().shape[0], 'quotes without None.')
# Out:
# If we do not take religion neither ethnic group, we have 111794 quotes without None.

# %% [markdown]
# I think the best compromise is to: drop `ethnic_group` column because too much None. Then we need to drop one between `religion` and `academic_degree`. I think that in our analysis, what is more relevant is to keep the `academic_degree`.

# %%
def create_observational_data(year, nb_chunk):
    chunks=[]
    for i in range(nb_chunk):
        chunk = pd.read_json(DATA_FOLDER+f'chunk-{str(i+1)}-{year}.json.bz2')
        chunk.drop(['religion', 'ethnic_group'], axis = 1, inplace = True)
        chunk.dropna(inplace = True)
        chunks.append(chunk)
        df_obs = pd.concat(chunks)
        df_obs.reset_index(drop=True, inplace=True)
        df_obs.to_json(DATA_FOLDER + f'observational-{year}.json.bz2')

# %%
create_observational_data('2018', 13)

# %%
create_observational_data('2017-after', 4)

# %%
create_observational_data('2017-before', 9)

# %%
quotes_2018 = pd.read_json(DATA_FOLDER+f'observational-2018.json.bz2')
quotes_2020 = pd.read_json(DATA_FOLDER+f'observational-2020.json.bz2')

# %%
quotes_2020 = pd.read_json(DATA_FOLDER+f'observational-2020.json.bz2')

# %%
quotes_2020
# Out:
#                                                 quotation  \
# 11      [ These ] actions will allow households who ha...
# 12        be pivotal in addressing financial frustrations
# 13      We're talking about `Do we want to continue th...
# 14      President Trump's State of the Union address p...
# 15      reallocating funding and [ prioritizing ] shel...
# ...                                                   ...
# 716281               My 3 year old is having a rough time
# 716452  I think most businesses and certainly the behe...
# 716553  Every place must identify its strongest, most ...
# 716813  The Federal Government is of the opinion that ...
# 716860  That Stripling projects the biblical stories i...
#
#                     speaker       qids  numOccurrences  gender  age  \
# 11               Ben Carson    Q816459               1    male   69
# 12               Ben Carson    Q816459               1    male   69
# 13               Ben Carson    Q816459               1    male   69
# 14               Ben Carson    Q816459               1    male   69
# 15               Ben Carson    Q816459               1    male   69
# ...                     ...        ...             ...     ...  ...
# 716281         Moshe Marcus  Q15454525               1    male   83
# 716452        Edmund Phelps    Q192566              16    male   87
# 716553  Robert Merton Solow    Q157268               1    male   96
# 716813      Margarete Bause   Q1894938               1  female   61
# 716860       Susanne Scholz  Q17326459               1  female   54
#
#                                                occupation  \
# 11      [psychologist, neurosurgeon, politician, autho...
# 12      [psychologist, neurosurgeon, politician, autho...
# 13      [psychologist, neurosurgeon, politician, autho...
# 14      [psychologist, neurosurgeon, politician, autho...
# 15      [psychologist, neurosurgeon, politician, autho...
# ...                                                   ...
# 716281                                    [mathematician]
# 716452                    [economist, university teacher]
# 716553         [economist, university teacher, professor]
# 716813                                       [politician]
# 716860                                        [professor]
#
#                academic_degree
# 11        [Doctor of Medicine]
# 12        [Doctor of Medicine]
# 13        [Doctor of Medicine]
# 14        [Doctor of Medicine]
# 15        [Doctor of Medicine]
# ...                        ...
# 716281             [doctorate]
# 716452             [doctorate]
# 716553  [Doctor of Philosophy]
# 716813                [Diplom]
# 716860             [doctorate]
#
# [46305 rows x 8 columns]

# %%
quotes_2015 = pd.read_json(DATA_FOLDER+f'observational-2015.json.bz2')
quotes_2016 = pd.read_json(DATA_FOLDER+f'observational-2016.json.bz2')
quotes_2017_before = pd.read_json(DATA_FOLDER+f'observational-2017-before.json.bz2')
quotes_2017_after = pd.read_json(DATA_FOLDER+f'observational-2017-after.json.bz2')
quotes_2018 = pd.read_json(DATA_FOLDER+f'observational-2018.json.bz2')
quotes_2019 = pd.read_json(DATA_FOLDER+f'observational-2019.json.bz2')
quotes_2020 = pd.read_json(DATA_FOLDER+f'observational-2018.json.bz2')

# %%
quotes_2015['label'] = 0
quotes_2016['label'] = 0
quotes_2017_before['label'] = 0
quotes_2017_after['label'] = 1
quotes_2018['label'] = 1
quotes_2019['label'] = 1
quotes_2020['label'] = 1

# %%
quotes_2015['year'] = 2015
quotes_2016['year'] = 2016
quotes_2017_before['year'] = 2017
quotes_2017_after['year'] = 2017
quotes_2018['year'] = 2018
quotes_2019['year'] = 2019
quotes_2020['year'] = 2020

# %%
quotes = pd.concat([quotes_2015, quotes_2016, quotes_2017_before, 
                    quotes_2017_after, quotes_2018, quotes_2019, quotes_2020])

# %%
quotes
# Out:
#                                                 quotation  \
# 0       I am convinced that this conflict won't be sol...
# 1       agreed that the E.U. should take further measu...
# 2       Germany will continue to do everything to supp...
# 3       There has already been voluntary debt forgiven...
# 4       They can be lifted if the reasons why they wer...
# ...                                                   ...
# 329687  Our contribution to WFP will directly address ...
# 329688  The oligarchs are competing with each another ...
# 329689  uncover and prevent many sabotage plots of the...
# 329690  We really should look at our planet like a Ros...
# 329691  Where people are involved, human error can nev...
#
#                      speaker      qids  numOccurrences  gender  age  \
# 0              Angela Merkel      Q567               1  female   61
# 1              Angela Merkel      Q567               6  female   61
# 2              Angela Merkel      Q567               1  female   61
# 3              Angela Merkel      Q567               1  female   61
# 4              Angela Merkel      Q567               1  female   61
# ...                      ...       ...             ...     ...  ...
# 329687           Cyrill Nunn  Q1148757               1    male   60
# 329688  Konstantin Remchukov  Q4393205               1    male   64
# 329689      Nguyen Phu Trong   Q318458               5    male   74
# 329690      Lisa Kaltenegger  Q4511414               5  female   41
# 329691     Oskar Niedermayer  Q2033892               2    male   66
#
#                                             occupation  \
# 0       [politician, physicist, statesperson, chemist]
# 1       [politician, physicist, statesperson, chemist]
# 2       [politician, physicist, statesperson, chemist]
# 3       [politician, physicist, statesperson, chemist]
# 4       [politician, physicist, statesperson, chemist]
# ...                                                ...
# 329687                                      [diplomat]
# 329688                        [politician, journalist]
# 329689                                    [politician]
# 329690     [astronomer, physicist, university teacher]
# 329691       [political scientist, university teacher]
#
#                                           academic_degree  label  year
# 0                                             [doctorate]      0  2015
# 1                                             [doctorate]      0  2015
# 2                                             [doctorate]      0  2015
# 3                                             [doctorate]      0  2015
# 4                                             [doctorate]      0  2015
# ...                                                   ...    ...   ...
# 329687                                        [doctorate]      1  2020
# 329688                   [Candidate of Economic Sciences]      1  2020
# 329689  [Candidate of Historical Sciences, Doctor of P...      1  2020
# 329690                                        [doctorate]      1  2020
# 329691                                        [doctorate]      1  2020
#
# [1768458 rows x 10 columns]

# %%
quotes.reset_index(drop=True, inplace = True)

# %%
quotes
# Out:
#                                                  quotation  \
# 0        I am convinced that this conflict won't be sol...
# 1        agreed that the E.U. should take further measu...
# 2        Germany will continue to do everything to supp...
# 3        There has already been voluntary debt forgiven...
# 4        They can be lifted if the reasons why they wer...
# ...                                                    ...
# 1768453  Our contribution to WFP will directly address ...
# 1768454  The oligarchs are competing with each another ...
# 1768455  uncover and prevent many sabotage plots of the...
# 1768456  We really should look at our planet like a Ros...
# 1768457  Where people are involved, human error can nev...
#
#                       speaker      qids  numOccurrences  gender  age  \
# 0               Angela Merkel      Q567               1  female   61
# 1               Angela Merkel      Q567               6  female   61
# 2               Angela Merkel      Q567               1  female   61
# 3               Angela Merkel      Q567               1  female   61
# 4               Angela Merkel      Q567               1  female   61
# ...                       ...       ...             ...     ...  ...
# 1768453           Cyrill Nunn  Q1148757               1    male   60
# 1768454  Konstantin Remchukov  Q4393205               1    male   64
# 1768455      Nguyen Phu Trong   Q318458               5    male   74
# 1768456      Lisa Kaltenegger  Q4511414               5  female   41
# 1768457     Oskar Niedermayer  Q2033892               2    male   66
#
#                                              occupation  \
# 0        [politician, physicist, statesperson, chemist]
# 1        [politician, physicist, statesperson, chemist]
# 2        [politician, physicist, statesperson, chemist]
# 3        [politician, physicist, statesperson, chemist]
# 4        [politician, physicist, statesperson, chemist]
# ...                                                 ...
# 1768453                                      [diplomat]
# 1768454                        [politician, journalist]
# 1768455                                    [politician]
# 1768456     [astronomer, physicist, university teacher]
# 1768457       [political scientist, university teacher]
#
#                                            academic_degree  label  year
# 0                                              [doctorate]      0  2015
# 1                                              [doctorate]      0  2015
# 2                                              [doctorate]      0  2015
# 3                                              [doctorate]      0  2015
# 4                                              [doctorate]      0  2015
# ...                                                    ...    ...   ...
# 1768453                                        [doctorate]      1  2020
# 1768454                   [Candidate of Economic Sciences]      1  2020
# 1768455  [Candidate of Historical Sciences, Doctor of P...      1  2020
# 1768456                                        [doctorate]      1  2020
# 1768457                                        [doctorate]      1  2020
#
# [1768458 rows x 10 columns]

# %%
quotes.to_json(DATA_FOLDER + 'data_observational.json.bz2')
